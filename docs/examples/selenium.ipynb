# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By

ChromePath = 'geokodriver.exe'
url = 'https://www.mgm.gov.tr/kurumsal/istasyonlarimiz.aspx'
browser = webdriver.Chrome(r'')
browser.get(url)

sehirler = ["İzmir", "Aydın"]
result_xy_list = []

for il in sehirler:
    sayi = 2
    xpath = f"/html/body/div[3]/div/div/div/div/div/div[1]/select/option[text()='{il}']"
    browser.find_element(By.XPATH, xpath).click()

    # check
    act_title = browser.title
    exp_title = "İstasyon Bilgileri Veritabanı - Meteoroloji Genel Müdürlüğü" 
    if act_title == exp_title:
        print("Passed")
    else:
        print("Failed")
    # wait for response
    time.sleep(3)
    
    # get link
    loops = browser.find_elements(By.XPATH, '//*[@id="ayrinti"]/table/tbody/tr/td/a')

    # split/rearrange x-y
    for loop in loops:
        # Find the district element associated with the station
        ilce_element = browser.find_elements(By.XPATH, f'//*[@id="ayrinti"]/table/tbody/tr[{sayi}]/td[5]')
        ilce_text_list = [ilce.text for ilce in ilce_element if ilce.text.strip()]
        print(f"Ilce text list for {il}: {ilce_text_list}")
        
        # Find the station number element associated with the station
        station_no_element = browser.find_elements(By.XPATH, f'//*[@id="ayrinti"]/table/tbody/tr[{sayi}]/td[3]')
        station_no_text = station_no_element[0].text if station_no_element else ""
        print(f"Station number for {il}: {station_no_text}")
        
        # Extract X and Y coordinates
        loop_1 = loop.get_attribute('href')
        result_1 = loop_1.split('=', 2)[2]
        result_x, result_y = result_1.split(',', 1)
        
        # Append data to the result list
        result_xy_list.append([il, ", ".join(ilce_text_list), station_no_text, result_x, result_y])
        
        # Increment sayi for the next iteration
        sayi += 1

# export
print(result_xy_list)
result_xy_list_csv = pd.DataFrame(result_xy_list, columns=["Sehir", "Ilce", "Station No", "X", "Y"])
print(result_xy_list_csv)

result_xy_list_csv.to_csv(r"C:\Users\Baleo\Desktop\DATA\2024\meteoroloji\data_TR.csv", index=False, encoding="utf-8")
# Out:
# The chromedriver version (120.0.6099.109) detected in PATH at C:\Program Files (x86)\webdrivers\chromedriver.exe might not be compatible with the detected chrome version (121.0.6167.189); currently, chromedriver 121.0.6167.184 is recommended for chrome 121.*, so it is advised to delete the driver in PATH and retry
# Passed
# Ilce text list for İzmir: ['Urla']
# Station number for İzmir: 18028
# Ilce text list for İzmir: ['Gaziemir']
# Station number for İzmir: 17219
# Ilce text list for İzmir: ['Torbalı']
# Station number for İzmir: 18030
# Ilce text list for İzmir: ['Aliağa']
# Station number for İzmir: 18038
# Ilce text list for İzmir: ['Menderes']
# Station number for İzmir: 18050
# Ilce text list for İzmir: ['Tire']
# Station number for İzmir: 18029
# Ilce text list for İzmir: ['Bornova']
# Station number for İzmir: 18031
# Ilce text list for İzmir: ['Karaburun']
# Station number for İzmir: 18032
# Ilce text list for İzmir: ['Bayındır']
# Station number for İzmir: 18049
# ...

# %%
//*[@id="ilAyrintiLabel"]/span

//*[@id="ilAyrintiLabel"]/span

<span style="font-weight: 700;" ng-bind="ilIstasyonSondurumlar[0].istInfo.il" class="ng-binding" xpath="1">Denizli</span>

<span style="font-weight: 700;" ng-bind="ilIstasyonSondurumlar[0].istInfo.il" class="ng-binding" xpath="1">Konya</span>

# %%
ddd = browser.find_element(By.XPATH, '//*[@id="ayrinti"]/table').text()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ddd = browser.find_element(By.XPATH, '//*[@id="ayrinti"]/table').text()
#
# File c:\Users\Baleo\anaconda3\envs\kentcbs\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\Baleo\anaconda3\envs\kentcbs\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
# ...

# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains

ChromePath = 'geokodriver.exe'
url = 'https://www.mgm.gov.tr/sondurum/turkiye.aspx'
browser = webdriver.Chrome(r'')
browser.get(url)


actions = ActionChains(browser)
map = browser.find_elements(By.CLASS_NAME, "leafletinteractive")

print(len(map))







#bir = browser.find_elements(By.XPATH, "//*[@id='map']/div[2]/div[3]/svg/g")
#time.sleep(3)  # Add a wait of 3 seconds
#konum = f"//*[@id='map']/div[2]/div[3]/svg/g[contains(text(), '441L444')]"
#browser.find_element(By.XPATH, konum).click()
#print(bir)
#print(konum)
# Out:
# The chromedriver version (120.0.6099.109) detected in PATH at C:\Program Files (x86)\webdrivers\chromedriver.exe might not be compatible with the detected chrome version (121.0.6167.189); currently, chromedriver 121.0.6167.184 is recommended for chrome 121.*, so it is advised to delete the driver in PATH and retry
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[36], line 14
#      10 browser.get(url)
#      13 actions = ActionChains(browser)
# ---> 14 map = browser.find_element(By.XPATH, "//*[@id='map']/div[2]/div[3]/svg")
#      16 move_to_element_with_offset(map, 40, 40).click().perform()
#      24 #bir = browser.find_elements(By.XPATH, "//*[@id='map']/div[2]/div[3]/svg/g")
#      25 #time.sleep(3)  # Add a wait of 3 seconds
#      26 #konum = f"//*[@id='map']/div[2]/div[3]/svg/g[contains(text(), '441L444')]"
#      27 #browser.find_element(By.XPATH, konum).click()
# ...

# %%
<h4 xpath="1">Kastamonu</h4>

<span style="font-weight: 700;" ng-bind="ilIstasyonSondurumlar[0].istInfo.il" class="ng-binding" xpath="1">Zonguldak</span>

# %%
//*[@id="map"]/div[2]/div[3]/svg/g/path[61]
//*[@id="map"]/div[2]/div[3]/svg/g

<svg pointer-events="none" class="leaflet-zoom-animated" width="1392" height="600" viewBox="-141 -152 1392 600" style="transform: translate3d(-141px, -152px, 0px);" xpath="1"><g><path class="leaflet-interactive" stroke="#808080" stroke-opacity="1" stroke-width="0.3" stroke-linecap="round" stroke-linejoin="round" fill="#fff" fill-opacity="0.9" fill-rule="evenodd" d="M356 214L354 211L357 199L363 194L363 189L360 186L361 185L364 185L382 195L400 202L404 202L405 204L401 207L403 209L399 217L392 220L389 218L383 219L382 216L379 218L372 214L362 212z"></path><path class="leaflet-interactive" stroke="#808080" stroke-opacity="1" stroke-width="0.3" stroke-linecap="round" stroke-linejoin="round" fill="#fff" fill-opacity="0.9" fill-rule="evenodd" d="M442 208L442 211L439 216L433 214L431 218L428 218L425 214L415 228L412 228L413 226L401 218L400 215L402 214L404 206L407 203L430 207z"></path><path class="leaflet-interactive" stroke="#808080" stroke-opacity="1" stroke-width="0.3" stroke-linecap="round" stroke-linejoin="round" fill="#fff" fill-opacity="0.9" fill-rule="evenodd" d="M412 230L412 229z"></path><path class="leaflet-interactive" stroke="#808080" stroke-opacity="1" stroke-width="0.3" stroke-linecap="round" stroke-linejoin="round" fill="#fff" fill-opacity="0.9" fill-rule="evenodd" d="M399 249L390 246L390 244L400 238L413 237L423 234L426 236L421 237L423 242L420 244L416 243L409 245L400 243z"></path><path class="leaflet-interactive" stroke="#808080" stroke-opacity="1" stroke-width="0.3" stroke-linecap="round" stroke-linejoin="round" fill="#fff" fill-opacity="0.9" fill-rule="evenodd" d="M335 238L342 238L342 240L337 242L333 241L333 239z"></path><path class="leaflet-interactive" stroke="#808080" stroke-opacity="1" stroke-width="0.3" stroke-linecap="round" stroke-linejoin="round" fill="#fff" fill-opacity="0.9" fill-rule="evenodd" d="M289 316L289 316z"></path><path class="leaflet-interactive" stroke="#808080" stroke-opacity="1" stroke-width="0.3" stroke-linecap="round" stroke-linejoin="round" fill="#fff" fill-opacity="0.9" fill-rule="evenodd" d="M379 245L378 246z"></path><path class="leaflet-interactive" stroke="#808080" stroke-opacity="1" stroke-width="0.3" stroke-linecap="round" stroke-linejoin="round" fill="#fff" fill-opacity="0.9" fill-rule="evenodd" d="M299 238L300 233L308 233L310 236L308 240L309 243L297 248L295 252L292 253L290 258L280 265L281 268L277 272L272 274L276 265L276 262L273 258L284 250L301 242L300 238z"></path><path class="leaflet-interactive" stroke="#808080" stroke-opacity="1" stroke-width="0.3" stroke-linecap="round" stroke-linejoin="round" fill="#fff" fill-opacity="0.9" fill-rule="evenodd" d="M261 263L261 269L256 271L251 271L248 269L250 266L261 262z"></path><path class="leaflet-interactive" stroke="#808080" stroke-opacity="1" stroke-width="0.3" stroke-linecap="round" stroke-linejoin="round" fill="#fff" fill-opacity="0.9" fill-rule="evenodd" d="M266 281L266 281z"></path><path class="leaflet-interactive" stroke="#808080" stroke-opacity="1" stroke-width="0.3" stroke-linecap="round" stroke-linejoin="round" fill="#fff" fill-opacity="0.9" fill-rule="evenodd" d="