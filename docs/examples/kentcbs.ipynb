# %%
import kentcbs
from ipyleaflet import Map, Marker, MarkerCluster, Popup, SearchControl

# %%
url ="https://nominaim.openstreetmap.org/search?format=json&q={s}"

# %%
m = kentcbs.Map(zoom=3, center=[19.1646, 72.8493])


m.add(SearchControl(
  position="topleft",
  url='https://nominatim.openstreetmap.org/search?format=json&q={s}',
  zoom=5,
))

m
# Out:
# Map(center=[19.1646, 72.8493], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
m.add_search_control(position='topleft', zoom=4, url=url)

# %%
>>> import xyzservices.providers as xyz

# %%
xyz.Thunderforest
# Out:
# {'OpenCycleMap': {'url': 'https://{s}.tile.thunderforest.com/{variant}/{z}/{x}/{y}.png?apikey={apikey}',
#   'html_attribution': '&copy; <a href="http://www.thunderforest.com/">Thunderforest</a>, &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors',
#   'attribution': '(C) Thunderforest, (C) OpenStreetMap contributors',
#   'variant': 'cycle',
#   'apikey': '<insert your api key here>',
#   'max_zoom': 22,
#   'name': 'Thunderforest.OpenCycleMap'},
#  'Transport': {'url': 'https://{s}.tile.thunderforest.com/{variant}/{z}/{x}/{y}.png?apikey={apikey}',
#   'html_attribution': '&copy; <a href="http://www.thunderforest.com/">Thunderforest</a>, &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors',
#   'attribution': '(C) Thunderforest, (C) OpenStreetMap contributors',
#   'variant': 'transport',
#   'apikey': '<insert your api key here>',
#   'max_zoom': 22,
#   'name': 'Thunderforest.Transport'},
# ...

# %%
https://{s}.tile.thunderforest.com/{Landscape}/{z}/{x}/{y}.png?apikey={apikey}
# Out:
#   Cell In[25], line 1
#     https://{s}.tile.thunderforest.com/{Landscape}/{z}/{x}/{y}.png?apikey={apikey}
#           ^
# SyntaxError: invalid syntax

# %%
m.add_tile_layer(url='https://{s}.tile.thunderforest.com/{Landscape}/{z}/{x}/{y}.png?apikey={apikey}', name='Thunderforest', attr='Thunderforest')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 m.add_tile_layer(url='https://{s}.tile.thunderforest.com/{Landscape}/{z}/{x}/{y}.png?apikey={apikey}', name='Thunderforest', attr='Thunderforest')
#
# AttributeError: 'Map' object has no attribute 'add_tile_layer'
